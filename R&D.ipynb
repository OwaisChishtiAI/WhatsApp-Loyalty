# %%
import easyocr
reader = easyocr.Reader(['ch_sim','en'])
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
result = reader.readtext('samples/IMG-20211209-WA0038.jpg')

# %%
result
# Out:
# [([[93, 83], [614, 83], [614, 247], [93, 247]], 'YCOR', 0.12427280843257904),
#  ([[49, 261], [429, 261], [429, 301], [49, 301]],
#   'AlI We Hove is NOW',
#   0.40541447308503614),
#  ([[462, 259], [579, 259], [579, 313], [462, 313]],
#   'Enjoy',
#   0.9808907920107853),
#  ([[95, 321], [336, 321], [336, 357], [95, 357]],
#   'COB Bakery # More',
#   0.7640441349157835),
#  ([[353, 324], [547, 324], [547, 361], [353, 361]],
#   'Kharnis Mushait',
#   0.8218603568303956),
#  ([[166, 362], [474, 362], [474, 401], [166, 401]],
#   'al-all IYAIIILlL Ludl',
#   0.0123347126140073),
#  ([[140, 427], [361, 427], [361, 465], [140, 465]],
#   '310454468700003',
#   0.980003452539362),
#  ([[190, 506], [246, 506], [246, 530], [190, 530]],
#   '!4',
#   0.019030327570396965),
#  ([[278, 506], [334, 506], [334, 530], [278, 530]],
#   '4 ^',
#   0.27834102372434916),
#  ([[333, 501], [457, 501], [457, 539], [333, 539]],
#   'pLo 1 E,Wi',
#   0.0034509417410560216),
# ...

# %%
for e in result:
    print(e[1])
# Out:
# APPLEBEE '5
# NEIBHBORHCJU GRII
#  BAR
# 3340 $
# Malyland Palkway
# Las Vegas, Nevada
# 89109
# 702-737-4990
# MARICELA
# 1 .
# 78#21
# [)4!E: 12-01-18 IINI =
# Ui:44 HN GUESTS;
# Mii:Ck #:8267.-136464
# ACIN IPA BTL
# 1:
# LABUIi IPA BTL
# 5.0g
# SAM ADAMS 8RW
# 7.49
# GOOSE IPA 8R
# 7.49
# CLS SAMP CONBU
# 13.49
# CHX PARIESAA
# 14.49
# GRCRSP& BOZSTK
# 19.99
# BB0 BRSK TAC0
# 10.99
# NA STR LM ENCHR
# 3.95
# NON ALCOHOLLC
# LAGUN IP! (i!
# 5.09
# SAM SEAS [R
# 7.49
# GOOSE IPA RRli
# 7.49
# SAM ADAMS BRW
# 1.49
# We Value yCUI` feedback!
# Visit
# WWW .talkloapplebees .CO i
# tle next
# 3 days
# & tell Us aboult
# yUUT' experiencc
# To enter the sulyey
# Will Ieed
# t0 Use the Folluwing eocle-
# 米{米木术木米*
# Survey Code=
# 8267120146431
# 本*米米
# Check TUTAL:
# 115.6!
# TAX:
# 9.5
# Tota1
# [JLIe
# 125
# 23
# Bratuity Examles
# 15 % Tin
# $18.78
# 18 % Tin = $22.54
# 20 % Tip
# $25.05
# DUPLICATE
# #
# 4
# 米米*牛*半卡木卡卡牛卡礻米 *米末米卡卡米末术米米*十*木牛宋*米木*木
# Thank yOu fur joining Us today !
# ...

# %%
import os
samples = os.listdir("samples")
samples
# Out:
# ['cafe-1.jpg',
#  'receipt_00000.png',
#  'receipt_00001.png',
#  'receipt_00002.png',
#  'receipt_00003.png',
#  'receipt_00004.png',
#  'receipt_00005.png',
#  'receipt_00006.png',
#  'receipt_00007.png',
#  'receipt_00008.png',
#  'receipt_00009.png',
#  'receipt_00010.png',
#  'receipt_00011.png',
#  'receipt_00012.png',
#  'receipt_00013.png',
#  'receipt_00014.png',
#  'receipt_00015.png',
#  'receipt_00016.png',
#  'receipt_00017.png',
#  'receipt_00018.png',
#  'receipt_00019.png',
#  'receipt_00020.png',
#  'receipt_00021.png',
#  'receipt_00022.png',
#  'receipt_00023.png',
#  'receipt_00024.png',
#  'receipt_00025.png',
#  'receipt_00026.png',
#  'receipt_00027.png',
#  'receipt_00028.png',
#  'receipt_00029.png',
#  'receipt_00030.png',
#  'receipt_00031.png',
#  'receipt_00032.png',
#  'receipt_00033.png',
#  'receipt_00034.png',
#  'receipt_00035.png',
#  'receipt_00036.png',
#  'receipt_00037.png',
#  'receipt_00038.png',
#  'receipt_00039.png',
# ...

# %%
data = []
for each in samples:
    print("Processing: ", each)
    result = reader.readtext("samples/" + each)
    data.append([x[1] for x in result])
print(len(samples))
print(len(data))
# Out:
# Processing:  cafe-1.jpg
# Processing:  receipt_00000.png
# Processing:  receipt_00001.png
# Processing:  receipt_00002.png
# Processing:  receipt_00003.png
# Processing:  receipt_00004.png
# Processing:  receipt_00005.png
# Processing:  receipt_00006.png
# Processing:  receipt_00007.png
# Processing:  receipt_00008.png
# Processing:  receipt_00009.png
# Processing:  receipt_00010.png
# Processing:  receipt_00011.png
# Processing:  receipt_00012.png
# Processing:  receipt_00013.png
# Processing:  receipt_00014.png
# Processing:  receipt_00015.png
# Processing:  receipt_00016.png
# Processing:  receipt_00017.png
# Processing:  receipt_00018.png
# Processing:  receipt_00019.png
# Processing:  receipt_00020.png
# Processing:  receipt_00021.png
# Processing:  receipt_00022.png
# Processing:  receipt_00023.png
# Processing:  receipt_00024.png
# Processing:  receipt_00025.png
# Processing:  receipt_00026.png
# Processing:  receipt_00027.png
# Processing:  receipt_00028.png
# ...

# %%
import pickle as pkl
with open("samples_text.pickle", "wb")as f:
    pkl.dump(data, f)

# %%
data[0]
# Out:
# ['Starbucks Coffee #16839',
#  'Pier',
#  'The Embarcadero',
#  'San FrancisCo, CA 415-956-3953',
#  'CHK 731564',
#  '05/12/201910:20 AM',
#  '2629940',
#  'Drawer:',
#  'Reg:',
#  '2',
#  'Vt Latte',
#  '4.55',
#  'Mastercard',
#  '4.55',
#  'XXKXXXXXXXXX2825',
#  'Subtotal',
#  '$4.55',
#  'Total',
#  '$4.55',
#  'Change',
#  'Due',
#  '$0',
#  'OO',
#  'Check Closed',
#  '05/12/201910:20 AM',
#  'Join our loyalty program',
#  'Starbucks Rewards@',
#  'Sign up for promotional',
#  'emails',
#  'Visit Starbucks . com/rewards',
#  'Or download our app',
#  'At participating stores',
#  'Some restrictions apply']

# %%
import re

# %%
re.findall(r'\d+', " ".join(data[0]))
# Out:
# ['16839',
#  '415',
#  '956',
#  '3953',
#  '731564',
#  '05',
#  '12',
#  '201910',
#  '20',
#  '2629940',
#  '2',
#  '4',
#  '55',
#  '4',
#  '55',
#  '2825',
#  '4',
#  '55',
#  '4',
#  '55',
#  '0',
#  '05',
#  '12',
#  '201910',
#  '20']

# %%
data[6]
# Out:
# ['TVII',
#  'Mo',
#  '5315',
#  'BAR',
#  'San',
#  'Francisco',
#  "InI ' ]",
#  'Airp',
#  'Dt',
#  '497',
#  'Mrtl',
#  'Lirik',
#  'Ruad',
#  'DATE:',
#  '02/21718',
#  'TIME',
#  '10:11',
#  'Pl',
#  'HasteFGard',
#  'Bredit',
#  'Larrl',
#  'Sale',
#  'CARD',
#  'M',
#  '5052',
#  'AHIIUNT',
#  '$',
#  '20',
#  '叫',
#  'AUTH',
#  '#',
#  '2845n',
#  'REF',
#  '#',
#  '166337',
#  'AHOUNI',
#  'AUTHIIRIZED',
#  '21.00',
#  'TRANS',
#  'U0',
#  'UTI',
#  '$',
#  'TKT7S',
#  'RE0',
#  '1',
#  '20.00',
#  'TKT7S',
#  '1SSUE0',
#  '1',
#  '20.00',
#  'B',
#  'S',
#  '00889196',
#  'TRANI',
#  '1',
#  '小',
#  '204845',
#  'Talks',
#  'Fur',
#  '[iding',
#  'BfRI']

# %%
" ".join(re.findall("[a-zA-Z]+", 'Tota1'))
# Out:
# 'Tota'

# %%
total_words = ['total', 'tota', 'amount', 'grandtotal', 'subtotal']

# %%
total_words
# Out:
# ['total', 'tota', 'amount', 'grandtotal', 'subtotal']

# %%
data
# Out:
# ['Starbucks Coffee #16839',
#  'Pier',
#  'The Embarcadero',
#  'San FrancisCo, CA 415-956-3953',
#  'CHK 731564',
#  '05/12/201910:20 AM',
#  '2629940',
#  'Drawer:',
#  'Reg:',
#  '2',
#  'Vt Latte',
#  '4.55',
#  'Mastercard',
#  '4.55',
#  'XXKXXXXXXXXX2825',
#  'Subtotal',
#  '$4.55',
#  'Total',
#  '$4.55',
#  'Change',
#  'Due',
#  '$0',
#  'OO',
#  'Check Closed',
#  '05/12/201910:20 AM',
#  'Join our loyalty program',
#  'Starbucks Rewards@',
#  'Sign up for promotional',
#  'emails',
#  'Visit Starbucks . com/rewards',
#  'Or download our app',
#  'At participating stores',
#  'Some restrictions apply']

# %%
"".join('$4.55')
# Out:
# '$4.55'

# %%
image = os.listdir('uploads/+923132609629')[0]
print("[INFO] Analyzing Image: ", image)
result = reader.readtext(os.path.join('uploads/+923132609629', image))
data = [x[1] for x in result]
total_index = None
for i in range(len(data)):
    if " ".join(re.findall("[a-zA-Z]+", data[i])).lower().strip() in total_words:
        total_index = i                
        break
if total_index is not None:
    try:
        for j in range(total_index+1, total_index+4):
            print(data[j])
            numbers = re.findall(r'\d+(?:[,.]\d+)*', "".join(data[j]))
            print("NN", numbers)
            if numbers:
                # print(numbers, type(numbers))
                print(float("".join(numbers)))
    except Exception as e:
        print("[Exception from read_receipt_rule_based]", str(e))
# Out:
# [INFO] Analyzing Image:  .jpg
# $4.55
# NN ['4.55']
# 4.55
# Total
# NN []
# $4.55
# NN ['4.55']
# 4.55

# %%
re.findall(r'\d+(?:[,.]\d+)*', '$ 4 . 5 5')
# Out:
# ['4', '5', '5']

# %%
total_index = None
total_value = None
each = data[6]
for i in range(len(each)):
    if " ".join(re.findall("[a-zA-Z]+", each[i])).lower().strip() in total_words:
        total_index = i
        print(i, each[i])
        break
if total_index is not None:
    print("Finding Value")
    for j in range(total_index+1, total_index+3):
        numbers = re.findall(r'\d+', " ".join(each[j]))
        if numbers:
            total_value = each[j]
            print(total_index, each[j])
            break
print("------------------------------------------------------------------")
# Out:
# ------------------------------------------------------------------

# %%
score = 0
tags = []
values = []
for each in data:
    total_index = None
    total_value = None
    for i in range(len(each)):
        if " ".join(re.findall("[a-zA-Z]+", each[i])).lower().strip() in total_words:
            total_index = i
            
            # print(i, each[i])
            break
    if total_index is not None:
        # print("Finding Value")
        try:
            for j in range(total_index+1, total_index+4):
                numbers = re.findall(r'\d+', " ".join(each[j]))
                if numbers:
                    total_value = each[j]
                    values.append("")
                    tags.append(each[i])
                    # print(total_index, each[j])
                    score+=1
                    break
        except Exception as e:
            print(data.index(each), str(e))
    print("------------------------------------------------------------------")
print("{0}/{1}".format(score, len(data)))
# assert(tags == values)
# Out:
# ------------------------------------------------------------------
# ------------------------------------------------------------------
# ------------------------------------------------------------------
# ------------------------------------------------------------------
# ------------------------------------------------------------------
# ------------------------------------------------------------------
# ------------------------------------------------------------------
# ------------------------------------------------------------------
# ------------------------------------------------------------------
# ------------------------------------------------------------------
# ------------------------------------------------------------------
# ------------------------------------------------------------------
# ------------------------------------------------------------------
# ------------------------------------------------------------------
# ...

# %%
list(zip(tags, values))
# Out:
# [('Subtotal', ['4', '5', '5']),
#  (' Subtotal', ['0', '0', '0']),
#  ('TOTA', ['9', '1', '0', '0', '0']),
#  ('SUBTOTAL', ['1', '1', '0', '0', '0']),
#  ('TOTAL', ['8', '1']),
#  ('TOTAL', ['4', '6']),
#  ('Total', ['5', '0', '0', '0', '0']),
#  ('SUBTOTAL', ['1', '7', '0', '0', '0']),
#  ('TOTAL', ['2', '3', '0']),
#  ('TOTAL', ['7', '0', '0', '0', '0']),
#  ('Total', ['7', '0', '0', '0', '0']),
#  ('TOTAL', ['9', '1', '0', '0', '0']),
#  ('TOTAL', ['4', '0', '0', '0', '0']),
#  ('TOTAL', ['6', '3', '0', '0', '0']),
#  ('TOTAL', ['4', '3', '0', '0', '0']),
#  ('Subtotal', ['1', '3', '8', '0', '0', '0']),
#  ('SUBTOTAL', ['5', '6', '0', '0', '0']),
#  ('TOTAL', ['4', '2', '6', '1', '9', '5']),
#  ('TOTAL', ['1', '1', '3', '8', '8', '6']),
#  ('TOTAL', ['1', '4', '8']),
#  ('TOTAL', ['5', '4']),
#  ('TOTAL', ['2', '0']),
#  ('Subtotal', ['5']),
#  ('Subtotal;', ['1', '5', '0', '0']),
#  ('TOTAL', ['0']),
#  ('TOTAL', ['0', '8']),
#  ('Total :', ['4', '0', '0', '0', '0']),
# ...

# %%
# Terminal
# curl -L "https://app.roboflow.com/ds/8t75Xe1PGw?key=WzLmG1oVIz" > roboflow.zip; unzip roboflow.zip; rm roboflow.zip

# Jupyter
# !pip install roboflow

# from roboflow import Roboflow
# rf = Roboflow(api_key="zJu0VPIaDjbZNZ7Tqaqx")
# project = rf.workspace().project("cord-public")
# dataset = project.version(1).download("yolov5")

# %%
from twilio.twiml.messaging_response import MessagingResponse
from twilio.rest import Client

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
client = Client()

# %%
from_whatsapp_number = 'whatsapp:+14155238886'
to_whatsapp_number = 'whatsapp:+923132609629'

message = client.messages.create(body='Check out this funny picture!',
                       media_url='https://static8.depositphotos.com/1006899/896/i/950/depositphotos_8961765-stock-photo-prize.jpg',
                       from_=from_whatsapp_number,
                       to=to_whatsapp_number)

# %%
import requests

url = 'https://app.nanonets.com/api/v2/OCR/Model/3e9d1eae-3e0f-4ac5-97e7-87400c4fc796/LabelFile/'

data = {'file': open('samples/cafe-1.jpg', 'rb')}

response = requests.post(url, auth=requests.auth.HTTPBasicAuth('68AfQsx5Q-G_LWU0O2BQjBT3CV1OLf-V', ''), files=data)

print(response)
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# D:\SoftwaresDir\envs\loyalty\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     705                 headers=headers,
# --> 706                 chunked=chunked,
#     707             )
#
# D:\SoftwaresDir\envs\loyalty\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# D:\SoftwaresDir\envs\loyalty\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ...

# %%
response.json()
# Out:
# {'message': 'Success',
#  'result': [{'message': 'Success',
#    'input': 'cafe-1.jpg',
#    'prediction': [{'id': '',
#      'label': 'Card_Tender',
#      'xmin': 432,
#      'ymin': 388,
#      'xmax': 483,
#      'ymax': 411,
#      'score': 0.60576653,
#      'ocr_text': '4.55'},
#     {'id': '',
#      'label': 'Card_Tender',
#      'xmin': 432,
#      'ymin': 420,
#      'xmax': 483,
#      'ymax': 442,
#      'score': 0.99995446,
#      'ocr_text': '4.55'},
#     {'id': '',
#      'label': 'Date',
#      'xmin': 153,
#      'ymin': 285,
#      'xmax': 283,
#      'ymax': 313,
#      'score': 0.99999976,
#      'ocr_text': '05/12/2019'},
#     {'id': '',
#      'label': 'Merchant_Name',
#      'xmin': 126,
#      'ymin': 121,
#      'xmax': 430,
#      'ymax': 146,
#      'score': 0.99917364,
#      'ocr_text': 'Starbucks Coffee #16839'},
#     {'id': '',
#      'label': 'Merchant_Address',
#      'xmin': 87,
#      'ymin': 152,
#      'xmax': 483,
#      'ymax': 213,
# ...

# %%
type(response.status_code)
# Out:
# int

# %%
import requests

url = 'https://app.nanonets.com/api/v2/OCR/Model/3e9d1eae-3e0f-4ac5-97e7-87400c4fc796/LabelFile/'

data = {'file': open('samples/cafe-1.jpg', 'rb')}

response = requests.post(url, auth=requests.auth.HTTPBasicAuth('68AfQsx5Q-G_LWU0O2BQjBT3CV1OLf-V', ''), files=data)

print(response.text)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# D:\SoftwaresDir\envs\loyalty\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     705                 headers=headers,
# --> 706                 chunked=chunked,
#     707             )
#
# D:\SoftwaresDir\envs\loyalty\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# D:\SoftwaresDir\envs\loyalty\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ...

# %%
import requests

url = 'https://app.nanonets.com/api/v2/OCR/Model/3e9d1eae-3e0f-4ac5-97e7-87400c4fc796/LabelFile/'

data = {'file': open('REPLACE_IMAGE_PATH.jpg', 'rb')}

response = requests.post(url, auth=requests.auth.HTTPBasicAuth('68AfQsx5Q-G_LWU0O2BQjBT3CV1OLf-V', ''), files=data)

print(response.text)

# %%
from imutils.perspective import four_point_transform
import argparse
import imutils
import cv2
import re

# %%
args = {"image" : "samples/receipt_00014.png"}

# %%
orig = cv2.imread(args["image"])
image = orig.copy()
image = imutils.resize(image, width=500)
ratio = orig.shape[1] / float(image.shape[1])

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
blurred = cv2.GaussianBlur(gray, (5, 5,), 0)
edged = cv2.Canny(blurred, 75, 200)
cv2.imshow("Input", image)
cv2.imshow("Edged", edged)
cv2.waitKey(0)
# Out:
# 113

# %%
cnts = cv2.findContours(edged.copy(), cv2.RETR_EXTERNAL,
	cv2.CHAIN_APPROX_SIMPLE)
cnts = imutils.grab_contours(cnts)
cnts = sorted(cnts, key=cv2.contourArea, reverse=True)
receiptCnt = None
# loop over the contours
for c in cnts:
	# approximate the contour
	peri = cv2.arcLength(c, True)
	approx = cv2.approxPolyDP(c, 0.02 * peri, True)
	# if our approximated contour has four points, then we can
	# assume we have found the outline of the receipt
	if len(approx) == 4:
		receiptCnt = approx
		break
# if the receipt contour is empty then our script could not find the
# outline and we should be notified
if receiptCnt is None:
	raise Exception(("Could not find receipt outline. "
		"Try debugging your edge detection and contour steps."))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b83c25cd1c85> in <module>
# ----> 1 cnts = cv2.findContours(edged.copy(), cv2.RETR_EXTERNAL,
#       2 	cv2.CHAIN_APPROX_SIMPLE)
#       3 cnts = imutils.grab_contours(cnts)
#       4 cnts = sorted(cnts, key=cv2.contourArea, reverse=True)
#       5 receiptCnt = None
#
# NameError: name 'cv2' is not defined

# %%
if args["debug"] > 0:
	output = image.copy()
	cv2.drawContours(output, [receiptCnt], -1, (0, 255, 0), 2)
	cv2.imshow("Receipt Outline", output)
	cv2.waitKey(0)
# apply a four-point perspective transform to the *original* image to
# obtain a top-down bird's-eye view of the receipt
receipt = four_point_transform(orig, receiptCnt.reshape(4, 2) * ratio)
# show transformed image
cv2.imshow("Receipt Transform", imutils.resize(receipt, width=500))
cv2.waitKey(0)

# %% [markdown]
# # Template Matching

# %%
import os
import cv2
from imutils import paths
import matplotlib.pyplot as plt

# %%
base_dir = "receipt_matcher/R&D"
folders = [base_dir+"/imtiaz", base_dir+"/kfc", base_dir+"/wallmart"]
files = {'imtiaz' : list(paths.list_images(folders[0])), 'kfc' : list(paths.list_images(folders[1])), 'wallmart' : list(paths.list_images(folders[2]))}

# %%
files
# Out:
# {'imtiaz': ['receipt_matcher/R&D/imtiaz\\1.jpg',
#   'receipt_matcher/R&D/imtiaz\\2.jpg',
#   'receipt_matcher/R&D/imtiaz\\cropped_1.jpg',
#   'receipt_matcher/R&D/imtiaz\\cropped_2.jpg'],
#  'kfc': ['receipt_matcher/R&D/kfc\\1.jpg',
#   'receipt_matcher/R&D/kfc\\2.jpeg',
#   'receipt_matcher/R&D/kfc\\3.jpg',
#   'receipt_matcher/R&D/kfc\\4.png',
#   'receipt_matcher/R&D/kfc\\cropped_1.jpg',
#   'receipt_matcher/R&D/kfc\\cropped_2.jpeg',
#   'receipt_matcher/R&D/kfc\\cropped_3.jpg',
#   'receipt_matcher/R&D/kfc\\cropped_4.png'],
#  'wallmart': ['receipt_matcher/R&D/wallmart\\2.jpg',
#   'receipt_matcher/R&D/wallmart\\4.jpg',
#   'receipt_matcher/R&D/wallmart\\5.jpg',
#   'receipt_matcher/R&D/wallmart\\6.jpg',
#   'receipt_matcher/R&D/wallmart\\7.jpg',
#   'receipt_matcher/R&D/wallmart\\8.jpg',
#   'receipt_matcher/R&D/wallmart\\9.png',
#   'receipt_matcher/R&D/wallmart\\cropped_2.jpg',
#   'receipt_matcher/R&D/wallmart\\cropped_4.jpg',
# ...

# %%
# test_file = files['imtiaz'][0]
for each in files.keys():
    for test_file in files[each]:
        print(test_file)
        test_img = cv2.imread(test_file)
        test_img = cv2.cvtColor(test_img, cv2.COLOR_BGR2GRAY)
        h, w = test_img.shape
        h = int(h * 0.3)
        x,y = 0, 0
        cropped_image = test_img[y:y+h, x:x+w]
#         plt.imshow(cropped_image)
        cv2.imwrite(test_file.split('\\')[0]+"/cropped_"+test_file.split('\\')[1], cropped_image)
        print("Image Saved.", test_file.split('\\')[0]+"/cropped_"+test_file.split('\\')[1])
# Out:
# receipt_matcher/imtiaz\1.jpg
# Image Saved. receipt_matcher/imtiaz/cropped_1.jpg
# receipt_matcher/imtiaz\2.jpg
# Image Saved. receipt_matcher/imtiaz/cropped_2.jpg
# receipt_matcher/kfc\1.jpg
# Image Saved. receipt_matcher/kfc/cropped_1.jpg
# receipt_matcher/kfc\2.jpeg
# Image Saved. receipt_matcher/kfc/cropped_2.jpeg
# receipt_matcher/kfc\3.jpg
# Image Saved. receipt_matcher/kfc/cropped_3.jpg
# receipt_matcher/kfc\4.png
# Image Saved. receipt_matcher/kfc/cropped_4.png
# receipt_matcher/wallmart\2.jpg
# Image Saved. receipt_matcher/wallmart/cropped_2.jpg
# receipt_matcher/wallmart\4.jpg
# Image Saved. receipt_matcher/wallmart/cropped_4.jpg
# receipt_matcher/wallmart\5.jpg
# Image Saved. receipt_matcher/wallmart/cropped_5.jpg
# receipt_matcher/wallmart\6.jpg
# Image Saved. receipt_matcher/wallmart/cropped_6.jpg
# receipt_matcher/wallmart\7.jpg
# Image Saved. receipt_matcher/wallmart/cropped_7.jpg
# receipt_matcher/wallmart\8.jpg
# Image Saved. receipt_matcher/wallmart/cropped_8.jpg
# ...

# %%
files = {'imtiaz' : [x for x in paths.list_images(folders[0]) if 'cropped' in x], 'kfc' : [x for x in paths.list_images(folders[1]) if 'cropped' in x], 'wallmart' : [x for x in paths.list_images(folders[2]) if 'cropped' in x]}

# %%
files
# Out:
# {'imtiaz': ['receipt_matcher/R&D/imtiaz\\cropped_1.jpg',
#   'receipt_matcher/R&D/imtiaz\\cropped_2.jpg'],
#  'kfc': ['receipt_matcher/R&D/kfc\\cropped_1.jpg',
#   'receipt_matcher/R&D/kfc\\cropped_2.jpeg',
#   'receipt_matcher/R&D/kfc\\cropped_3.jpg',
#   'receipt_matcher/R&D/kfc\\cropped_4.png'],
#  'wallmart': ['receipt_matcher/R&D/wallmart\\cropped_2.jpg',
#   'receipt_matcher/R&D/wallmart\\cropped_4.jpg',
#   'receipt_matcher/R&D/wallmart\\cropped_5.jpg',
#   'receipt_matcher/R&D/wallmart\\cropped_6.jpg',
#   'receipt_matcher/R&D/wallmart\\cropped_7.jpg',
#   'receipt_matcher/R&D/wallmart\\cropped_8.jpg',
#   'receipt_matcher/R&D/wallmart\\cropped_9.png']}

# %%
import cv2 
import matplotlib.pyplot as plt
# %matplotlib inline

# read images
img1 = cv2.imread(files['imtiaz'][0])  
img2 = cv2.imread(files['imtiaz'][1]) 
print(files['imtiaz'][0], files['imtiaz'][1])
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

#sift
sift = cv2.xfeatures2d.SIFT_create()

keypoints_1, descriptors_1 = sift.detectAndCompute(img1,None)
keypoints_2, descriptors_2 = sift.detectAndCompute(img2,None)

#feature matching
bf = cv2.BFMatcher(cv2.NORM_L1, crossCheck=True)

matches = bf.match(descriptors_1,descriptors_2)
matches = sorted(matches, key = lambda x:x.distance)
print(len(matches))

img3 = cv2.drawMatches(img1, keypoints_1, img2, keypoints_2, matches[:50], img2, flags=2)
plt.imshow(img3)
# Out:
# receipt_matcher/imtiaz\cropped_1.jpg receipt_matcher/imtiaz\cropped_2.jpg
# 508

# %%
def find_sift_matches(file1, file2):
    img1 = cv2.imread(file1)
    img2 = cv2.imread(file2)
    img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
    img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

    #sift
    sift = cv2.xfeatures2d.SIFT_create()

    keypoints_1, descriptors_1 = sift.detectAndCompute(img1,None)
    keypoints_2, descriptors_2 = sift.detectAndCompute(img2,None)

    #feature matching
    bf = cv2.BFMatcher(cv2.NORM_L1, crossCheck=True)

    matches = bf.match(descriptors_1,descriptors_2)
    matches = sorted(matches, key = lambda x:x.distance)
    return len(matches)

# %%
images = []
for each in files.keys():
    for test_file in files[each]:
        images.append(test_file)
images
# Out:
# ['receipt_matcher/R&D/imtiaz\\cropped_1.jpg',
#  'receipt_matcher/R&D/imtiaz\\cropped_2.jpg',
#  'receipt_matcher/R&D/kfc\\cropped_1.jpg',
#  'receipt_matcher/R&D/kfc\\cropped_2.jpeg',
#  'receipt_matcher/R&D/kfc\\cropped_3.jpg',
#  'receipt_matcher/R&D/kfc\\cropped_4.png',
#  'receipt_matcher/R&D/wallmart\\cropped_2.jpg',
#  'receipt_matcher/R&D/wallmart\\cropped_4.jpg',
#  'receipt_matcher/R&D/wallmart\\cropped_5.jpg',
#  'receipt_matcher/R&D/wallmart\\cropped_6.jpg',
#  'receipt_matcher/R&D/wallmart\\cropped_7.jpg',
#  'receipt_matcher/R&D/wallmart\\cropped_8.jpg',
#  'receipt_matcher/R&D/wallmart\\cropped_9.png']

# %%
for i in range(len(images)):
    for j in range(len(images)):
        base = images[i]
        matches = find_sift_matches(base, images[j])
        if base == images[j]:
            print(base.split("/")[1], images[j].split("/")[1], matches, " ↔ ↔ ↔ SAME")
        elif matches > 500:
            print(base.split("/")[1], images[j].split("/")[1], matches, " ■ ■ ■ > 500")
        else:
            print(base.split("/")[1], images[j].split("/")[1], matches)
# Out:
# imtiaz\cropped_1.jpg imtiaz\cropped_1.jpg 1671  ↔ ↔ ↔ SAME
# imtiaz\cropped_1.jpg imtiaz\cropped_2.jpg 508  ■ ■ ■ > 500
# imtiaz\cropped_1.jpg kfc\cropped_1.jpg 109
# imtiaz\cropped_1.jpg kfc\cropped_2.jpeg 343
# imtiaz\cropped_1.jpg kfc\cropped_3.jpg 113
# imtiaz\cropped_1.jpg kfc\cropped_4.png 193
# imtiaz\cropped_1.jpg wallmart\cropped_2.jpg 185
# imtiaz\cropped_1.jpg wallmart\cropped_4.jpg 280
# imtiaz\cropped_1.jpg wallmart\cropped_5.jpg 433
# imtiaz\cropped_1.jpg wallmart\cropped_6.jpg 153
# imtiaz\cropped_1.jpg wallmart\cropped_7.jpg 321
# imtiaz\cropped_1.jpg wallmart\cropped_8.jpg 572  ■ ■ ■ > 500
# imtiaz\cropped_1.jpg wallmart\cropped_9.png 172
# imtiaz\cropped_2.jpg imtiaz\cropped_1.jpg 508  ■ ■ ■ > 500
# imtiaz\cropped_2.jpg imtiaz\cropped_2.jpg 2176  ↔ ↔ ↔ SAME
# imtiaz\cropped_2.jpg kfc\cropped_1.jpg 109
# imtiaz\cropped_2.jpg kfc\cropped_2.jpeg 446
# imtiaz\cropped_2.jpg kfc\cropped_3.jpg 118
# imtiaz\cropped_2.jpg kfc\cropped_4.png 185
# ...

# %% [markdown]
# # Working on Text Similarity for Receipts

# %%
def get_header_text(file_name):
    result = reader.readtext(file_name)
    return " ".join([x[1] for x in result])

# %%
result = reader.readtext(files['imtiaz'][0])
result
# Out:
# [([[347, 7], [633, 7], [633, 112], [347, 112]], 'Ilgz', 0.05851694568991661),
#  ([[358, 106], [382, 106], [382, 132], [358, 132]], 'U', 0.4986244142351701),
#  ([[381, 100], [460, 100], [460, 141], [381, 141]],
#   '巴#',
#   0.0017837701956032281),
#  ([[471, 88], [625, 88], [625, 129], [471, 129]],
#   'TaTkat',
#   0.02557240168515494),
#  ([[247, 133], [621, 133], [621, 170], [247, 170]],
#   'R;e Tlrt Ohwlmir BxpBrinaae',
#   0.003747958295035783),
#  ([[362, 198], [398, 198], [398, 222], [362, 222]], 'Mal', 0.9766528896124871),
#  ([[433, 195], [546, 195], [546, 224], [433, 224]],
#   'GURANNALA',
#   0.7808582231877688),
#  ([[298, 214], [340, 214], [340, 238], [298, 238]], 'UMN', 0.2457093187037857),
#  ([[362, 218], [554, 218], [554, 242], [362, 242]],
#   '111  TMTCA?(4,,8429)',
#   0.16283499311379185),
#  ([[249, 237], [285, 237], [285, 253], [249, 253]],
#   'IWI',
#   0.13461945855755114),
#  ([[287, 233], [378, 233], [378, 261], [287, 261]],
#   'Tacebork',
# ...

# %%
data = [x[1] for x in result]
data
# Out:
# ['Ilgz',
#  'U',
#  '巴#',
#  'TaTkat',
#  'R;e Tlrt Ohwlmir BxpBrinaae',
#  'Mal',
#  'GURANNALA',
#  'UMN',
#  '111  TMTCA?(4,,8429)',
#  'IWI',
#  'Tacebork',
#  'ColIIilt1z upermiarket',
#  'Bsitlf12-02-9939-121-64',
#  'TCI No',
#  '07-501)978',
#  'Transacticr Date',
#  'ADr',
#  '21',
#  '2020 3;4 Py',
#  '8614',
#  'P0s I0 GUJ-SAL 01',
#  'Tar',
#  '8674',
#  'NIMS',
#  'TCalIsect',
#  'UIsar',
#  'GUJ',
#  'Usar',
#  'Namle']

# %%
text = " ".join(data)
text
# Out:
# 'Ilgz U 巴# TaTkat R;e Tlrt Ohwlmir BxpBrinaae Mal GURANNALA UMN 111  TMTCA?(4,,8429) IWI Tacebork ColIIilt1z upermiarket Bsitlf12-02-9939-121-64 TCI No 07-501)978 Transacticr Date ADr 21 2020 3;4 Py 8614 P0s I0 GUJ-SAL 01 Tar 8674 NIMS TCalIsect UIsar GUJ Usar Namle'

# %%
text2 = get_header_text(files['imtiaz'][1])

# %%
text2
# Out:
# 'ml9 9 「k91 口e Sopmng Rxperioew Tra Uitmte Sharfabad Express Retail Store UAN 111-IMTIAZ( 468429) WWN . facebook .cOm/imt iazsupermarket Gst#12-02-9999 124-64 Transaction No  11-2175260 Transaction Date; Mar 18,20205;39 PM User; 30238 POS ID :REXPOI-SAL-02'

# %%
import spacy
# this loads the wrapper
nlp = spacy.load('en_core_web_md')

# %%
# !spacy download en_core_web_md
# Out:
# ...
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')

# %%
search_doc = nlp(text)
main_doc = nlp(text2)

search_doc_no_stop_words = nlp(' '.join([str(t) for t in search_doc if not t.is_stop]))
main_doc_no_stop_words = nlp(' '.join([str(t) for t in main_doc if not t.is_stop]))

print(search_doc_no_stop_words.similarity(main_doc_no_stop_words))
# Out:
# 0.8031624301788542

# %%
def get_document_similarity(text, text2):
    search_doc = nlp(text)
    main_doc = nlp(text2)

    search_doc_no_stop_words = nlp(' '.join([str(t) for t in search_doc if not t.is_stop]))
    main_doc_no_stop_words = nlp(' '.join([str(t) for t in main_doc if not t.is_stop]))

    return search_doc_no_stop_words.similarity(main_doc_no_stop_words)

# %%
try:
    for i in range(len(images)):
        for j in range(len(images)):
            base = images[i]
    #         base_text = get_header_text(base)
    #         second_text = get_header_text(second_image)
            matches = get_document_similarity(get_header_text(base), get_header_text(images[j]))
    #         matches = find_sift_matches(base, images[j])
            if base == images[j]:
                print(base.split("/")[2], images[j].split("/")[2], matches, " ↔ ↔ ↔ SAME")
    #         elif matches > 500:
    #             print(base.split("/")[1], images[j].split("/")[1], matches, " ■ ■ ■ > 500")
            else:
                print(base.split("/")[2], images[j].split("/")[2], matches)
except Exception as e:
    print(str(e), i, j)
# Out:
# imtiaz\cropped_1.jpg imtiaz\cropped_1.jpg 1.0  ↔ ↔ ↔ SAME
# imtiaz\cropped_1.jpg imtiaz\cropped_2.jpg 0.8031624301788542
# imtiaz\cropped_1.jpg kfc\cropped_1.jpg 0.39207511392570715
# imtiaz\cropped_1.jpg kfc\cropped_2.jpeg 0.47725643727712525
# imtiaz\cropped_1.jpg kfc\cropped_3.jpg 0.7221774462677196
# D:\SoftwaresDir\envs\loyalty\lib\site-packages\ipykernel_launcher.py:8: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
# imtiaz\cropped_1.jpg kfc\cropped_4.png 0.0
# imtiaz\cropped_1.jpg wallmart\cropped_2.jpg 0.6184812205030955
# imtiaz\cropped_1.jpg wallmart\cropped_4.jpg 0.6766507541053891
# imtiaz\cropped_1.jpg wallmart\cropped_5.jpg 0.7667015256082003
# imtiaz\cropped_1.jpg wallmart\cropped_6.jpg 0.4955049233337384
# imtiaz\cropped_1.jpg wallmart\cropped_7.jpg 0.6427083909472977
# imtiaz\cropped_1.jpg wallmart\cropped_8.jpg 0.753805352783013
# imtiaz\cropped_1.jpg wallmart\cropped_9.png 0.566342634889872
# ...

# %% [markdown]
# imtiaz\cropped_1.jpg imtiaz\cropped_1.jpg 1.0  ↔ ↔ ↔ SAME
# imtiaz\cropped_1.jpg imtiaz\cropped_2.jpg 0.8031624301788542
